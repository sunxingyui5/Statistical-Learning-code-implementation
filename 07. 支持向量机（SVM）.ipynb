# %% [markdown]
# #### 支持向量机算法：
# #### 线性可分支持向量机学习算法——最大间隔法
# **输入**：线性可分训练数据集$T=\{(x_1,y_1),(x_2,y_2),...,(x_N,y_N) \}$，其中，$x_i\in X=R^n$，$y_i\in Y=\{-1,+1 \}$，$i=1,2,...,N$；
# **输出**：最大间隔分离超平面和分类决策函数。
# （1）构造并求解约束最优化问题：
# &emsp;&emsp;&emsp;${\underset{w,b}{min}}\frac{1}{2}||w||^2 $
# &emsp;&emsp;&emsp;$s.t.$&emsp;$y_i(w\cdot x+b)-1\ge 0$，$i=1,2,...N$
# &emsp;求解最优解$w^*$，$b^*$。
# （2）由此得到分离超平面：
# &emsp;&emsp;&emsp;$w\cdot x+b^*=0$
# &emsp;分类决策函数
# &emsp;&emsp;&emsp;$f(x)=sign(w^*\cdot x+b^*)$

# %%
import math
import random
import numpy as np

# %% [markdown]
# #### 加载文件
# $param fileName$:要加载的文件路径
# *return*: 数据集和标签集

# %%
def loadData(fileName):
    dataArr = []; labelArr = []
    fr = open(fileName)
    for line in fr.readlines():
        curLine = line.strip().split(',')
        dataArr.append([int(num) / 255 for num in curLine[1:]])
        if int(curLine[0]) == 0:
            labelArr.append(1)
        else:
            labelArr.append(-1)
            
    #返回数据集和标记
    return dataArr, labelArr

# %% [markdown]
# #### 定义支持向量机类
# $param trainDataList$:训练数据集
# $param trainLabelList$: 训练测试集
# $param sigma$: 高斯核中分母的$\sigma$
# $param C$:软间隔中的惩罚参数
# $param toler$:松弛变量
# $param i$:$\alpha$的下标
# $param testDataList$:测试数据集
# $param testLabelList$: 测试标签集

# %%
class SVM:
    # SVM相关参数初始化
    def __init__(self, trainDataList, trainLabelList, sigma = 10, C = 200, toler = 0.001):
        self.trainDataMat = np.mat(trainDataList) 
        self.trainLabelMat = np.mat(trainLabelList).T 

        self.m, self.n = np.shape(self.trainDataMat)
        self.sigma = sigma 
        self.C = C                           
        self.toler = toler                       

        self.k = self.calcKernel()             
        self.b = 0                              
        self.alpha = [0] * self.trainDataMat.shape[0] 
        self.E = [0 * self.trainLabelMat[i, 0] for i in range(self.trainLabelMat.shape[0])]
        self.supportVecIndex = []


    # 计算核函数
    def calcKernel(self):
        k = [[0 for i in range(self.m)] for j in range(self.m)]
        #循环遍历Xi
        for i in range(self.m):
            if i % 100 == 0:
                print('construct the kernel:', i, self.m)
            X = self.trainDataMat[i, :]
            for j in range(i, self.m):
                Z = self.trainDataMat[j, :]
                result = (X - Z) * (X - Z).T
                #分子除以分母后去指数，得到的即为高斯核结果
                result = np.exp(-1 * result / (2 * self.sigma**2))
                #将Xi*Xj的结果存放入k[i][j]和k[j][i]中
                k[i][j] = result
                k[j][i] = result
                
        #返回高斯核矩阵
        return k

    # 查看第i个α是否满足KKT条件
    def isSatisfyKKT(self, i):
        gxi =self.calc_gxi(i)
        yi = self.trainLabelMat[i]

        if (math.fabs(self.alpha[i]) < self.toler) and (yi * gxi >= 1):
            return True

        elif (math.fabs(self.alpha[i] - self.C) < self.toler) and (yi * gxi <= 1):
            return True

        elif (self.alpha[i] > -self.toler) and (self.alpha[i] < (self.C + self.toler)) \
                and (math.fabs(yi * gxi - 1) < self.toler):
            return True

        return False

    # 计算g(xi)
    def calc_gxi(self, i):
        gxi = 0
        index = [i for i, alpha in enumerate(self.alpha) if alpha != 0]
        #遍历每一个非零α
        for j in index:
            gxi += self.alpha[j] * self.trainLabelMat[j] * self.k[j][i]
        #求和结束后再单独加上偏置b
        gxi += self.b

        return gxi

    # 计算Ei
    def calcEi(self, i):
        gxi = self.calc_gxi(i)

        return gxi - self.trainLabelMat[i]

    # SMO中选择第二个变量
    def getAlphaJ(self, E1, i):
        E2 = 0
        maxE1_E2 = -1
        maxIndex = -1

        #获得Ei非0的对应索引组成的列表，列表内容为非0Ei的下标i
        nozeroE = [i for i, Ei in enumerate(self.E) if Ei != 0]
        #对每个非零Ei的下标i进行遍历
        for j in nozeroE:
            E2_tmp = self.calcEi(j)
            if math.fabs(E1 - E2_tmp) > maxE1_E2:
                maxE1_E2 = math.fabs(E1 - E2_tmp)
                E2 = E2_tmp
                maxIndex = j
        if maxIndex == -1:
            maxIndex = i
            while maxIndex == i:
                maxIndex = int(random.uniform(0, self.m))
            E2 = self.calcEi(maxIndex)
            
        #返回第二个变量的E2值以及其索引
        return E2, maxIndex

    def train(self, iter = 100):
        iterStep = 0; parameterChanged = 1

        while (iterStep < iter) and (parameterChanged > 0):
            print('iter:%d:%d'%( iterStep, iter))
            iterStep += 1
            parameterChanged = 0

            #循环遍历所有样本，用于找SMO中第一个变量
            for i in range(self.m):
                if self.isSatisfyKKT(i) == False:
                    E1 = self.calcEi(i)
                    E2, j = self.getAlphaJ(E1, i)

                    y1 = self.trainLabelMat[i]
                    y2 = self.trainLabelMat[j]
  
                    alphaOld_1 = self.alpha[i]
                    alphaOld_2 = self.alpha[j]

                    if y1 != y2:
                        L = max(0, alphaOld_2 - alphaOld_1)
                        H = min(self.C, self.C + alphaOld_2 - alphaOld_1)
                    else:
                        L = max(0, alphaOld_2 + alphaOld_1 - self.C)
                        H = min(self.C, alphaOld_2 + alphaOld_1)

                    if L == H:   continue
                    #计算α的新值
                    k11 = self.k[i][i]
                    k22 = self.k[j][j]
                    k21 = self.k[j][i]
                    k12 = self.k[i][j]
                    alphaNew_2 = alphaOld_2 + y2 * (E1 - E2) / (k11 + k22 - 2 * k12)
                    if alphaNew_2 < L:
                        alphaNew_2 = L
                    elif alphaNew_2 > H:
                        alphaNew_2 = H
                    alphaNew_1 = alphaOld_1 + y1 * y2 * (alphaOld_2 - alphaNew_2)

                    b1New = -1 * E1 - y1 * k11 * (alphaNew_1 - alphaOld_1) \
                            - y2 * k21 * (alphaNew_2 - alphaOld_2) + self.b
                    b2New = -1 * E2 - y1 * k12 * (alphaNew_1 - alphaOld_1) \
                            - y2 * k22 * (alphaNew_2 - alphaOld_2) + self.b

                    if (alphaNew_1 > 0) and (alphaNew_1 < self.C):
                        bNew = b1New
                    elif (alphaNew_2 > 0) and (alphaNew_2 < self.C):
                        bNew = b2New
                    else:
                        bNew = (b1New + b2New) / 2

                    self.alpha[i] = alphaNew_1
                    self.alpha[j] = alphaNew_2
                    self.b = bNew

                    self.E[i] = self.calcEi(i)
                    self.E[j] = self.calcEi(j)

                    if math.fabs(alphaNew_2 - alphaOld_2) >= 0.00001:
                        parameterChanged += 1

                print("iter: %d i:%d, pairs changed %d" % (iterStep, i, parameterChanged))

        # 全部计算结束后，重新遍历一遍α，查找里面的支持向量
        for i in range(self.m):
            if self.alpha[i] > 0:
                # 将支持向量的索引保存起来
                self.supportVecIndex.append(i)

    # 单独计算核函数
    def calcSinglKernel(self, x1, x2):
        result = (x1 - x2) * (x1 - x2).T
        result = np.exp(-1 * result / (2 * self.sigma ** 2))
        
        #返回结果
        return np.exp(result)


    # 对样本的标签进行预测
    def predict(self, x):
        result = 0
        for i in self.supportVecIndex:
            tmp = self.calcSinglKernel(self.trainDataMat[i, :], np.mat(x))
            result += self.alpha[i] * self.trainLabelMat[i] * tmp
        #求和项计算结束后加上偏置b
        result += self.b
        #使用sign函数返回预测结果
        return np.sign(result)


    # 测试
    def test(self, testDataList, testLabelList):
        errorCnt = 0
        for i in range(len(testDataList)):
            print('test:%d:%d'%(i, len(testDataList)))
            result = self.predict(testDataList[i])
            if result != testLabelList[i]:
                errorCnt += 1
                
        #返回正确率
        return 1 - errorCnt / len(testDataList)

# %%
# 获取训练集及标签
trainDataList, trainLabelList = loadData('Mnist/mnist_train.csv')

# 获取测试集及标签
testDataList, testLabelList = loadData('Mnist/mnist_test.csv')

#初始化SVM类
print('start init SVM')
svm = SVM(trainDataList[:1000], trainLabelList[:1000], 10, 200, 0.001)

# 开始训练
print('start to train')
svm.train()

# 开始测试
print('start to test')
accuracy = svm.test(testDataList[:100], testLabelList[:100])
print('the accuracy is:',accuracy)
# Out:
# start init SVM
# construct the kernel: 0 1000
# construct the kernel: 100 1000
# construct the kernel: 200 1000
# construct the kernel: 300 1000
# construct the kernel: 400 1000
# construct the kernel: 500 1000
# construct the kernel: 600 1000
# construct the kernel: 700 1000
# construct the kernel: 800 1000
# construct the kernel: 900 1000
# start to train
# iter:0:100
# iter: 1 i:1, pairs changed 1
# iter: 1 i:21, pairs changed 2
# iter: 1 i:22, pairs changed 3
# iter: 1 i:23, pairs changed 4
# iter: 1 i:24, pairs changed 5
# iter: 1 i:25, pairs changed 5
# iter: 1 i:26, pairs changed 5
# iter: 1 i:27, pairs changed 5
# iter: 1 i:28, pairs changed 6
# iter: 1 i:29, pairs changed 6
# iter: 1 i:30, pairs changed 6
# iter: 1 i:31, pairs changed 6
# iter: 1 i:33, pairs changed 6
# iter: 1 i:34, pairs changed 7
# iter: 1 i:35, pairs changed 8
# iter: 1 i:36, pairs changed 9
# iter: 1 i:37, pairs changed 10
# iter: 1 i:40, pairs changed 10
# iter: 1 i:43, pairs changed 10
# iter: 1 i:51, pairs changed 11
# iter: 1 i:56, pairs changed 12
# iter: 1 i:57, pairs changed 13
# iter: 1 i:58, pairs changed 14
# iter: 1 i:59, pairs changed 14
# iter: 1 i:61, pairs changed 14
# iter: 1 i:63, pairs changed 15
# iter: 1 i:65, pairs changed 15
# iter: 1 i:67, pairs changed 15
# iter: 1 i:68, pairs changed 16
# iter: 1 i:69, pairs changed 16
# iter: 1 i:70, pairs changed 17
# iter: 1 i:72, pairs changed 17
# iter: 1 i:75, pairs changed 17
# iter: 1 i:77, pairs changed 17
# iter: 1 i:78, pairs changed 17
# iter: 1 i:79, pairs changed 17
# iter: 1 i:81, pairs changed 17
# iter: 1 i:85, pairs changed 17
# iter: 1 i:87, pairs changed 17
# iter: 1 i:92, pairs changed 17
# iter: 1 i:93, pairs changed 17
# iter: 1 i:94, pairs changed 17
# iter: 1 i:95, pairs changed 17
# iter: 1 i:97, pairs changed 17
# iter: 1 i:99, pairs changed 17
# iter: 1 i:102, pairs changed 17
# iter: 1 i:104, pairs changed 17
# iter: 1 i:105, pairs changed 17
# iter: 1 i:110, pairs changed 17
# iter: 1 i:112, pairs changed 17
# iter: 1 i:113, pairs changed 17
# iter: 1 i:114, pairs changed 17
# iter: 1 i:116, pairs changed 17
# iter: 1 i:119, pairs changed 17
# iter: 1 i:122, pairs changed 17
# iter: 1 i:124, pairs changed 17
# iter: 1 i:128, pairs changed 17
# iter: 1 i:132, pairs changed 17
# iter: 1 i:133, pairs changed 17
# iter: 1 i:134, pairs changed 17
# iter: 1 i:137, pairs changed 17
# iter: 1 i:142, pairs changed 17
# iter: 1 i:143, pairs changed 17
# iter: 1 i:147, pairs changed 17
# iter: 1 i:152, pairs changed 17
# iter: 1 i:153, pairs changed 17
# iter: 1 i:160, pairs changed 17
# iter: 1 i:162, pairs changed 17
# iter: 1 i:163, pairs changed 17
# iter: 1 i:166, pairs changed 17
# iter: 1 i:168, pairs changed 17
# iter: 1 i:170, pairs changed 17
# iter: 1 i:174, pairs changed 17
# iter: 1 i:176, pairs changed 17
# iter: 1 i:177, pairs changed 17
# iter: 1 i:180, pairs changed 17
# iter: 1 i:183, pairs changed 17
# iter: 1 i:184, pairs changed 17
# iter: 1 i:192, pairs changed 17
# iter: 1 i:194, pairs changed 17
# iter: 1 i:197, pairs changed 17
# iter: 1 i:200, pairs changed 17
# iter: 1 i:204, pairs changed 17
# iter: 1 i:208, pairs changed 17
# iter: 1 i:209, pairs changed 17
# iter: 1 i:211, pairs changed 17
# iter: 1 i:212, pairs changed 17
# iter: 1 i:226, pairs changed 17
# iter: 1 i:227, pairs changed 17
# iter: 1 i:229, pairs changed 17
# iter: 1 i:231, pairs changed 17
# iter: 1 i:240, pairs changed 17
# iter: 1 i:247, pairs changed 17
# iter: 1 i:248, pairs changed 17
# iter: 1 i:249, pairs changed 17
# iter: 1 i:251, pairs changed 17
# iter: 1 i:252, pairs changed 17
# iter: 1 i:264, pairs changed 17
# iter: 1 i:267, pairs changed 17
# iter: 1 i:276, pairs changed 17
# iter: 1 i:283, pairs changed 17
# iter: 1 i:285, pairs changed 17
# iter: 1 i:286, pairs changed 17
# iter: 1 i:292, pairs changed 17
# iter: 1 i:293, pairs changed 17
# iter: 1 i:296, pairs changed 17
# iter: 1 i:303, pairs changed 17
# iter: 1 i:310, pairs changed 17
# iter: 1 i:313, pairs changed 17
# iter: 1 i:315, pairs changed 17
# iter: 1 i:326, pairs changed 17
# iter: 1 i:343, pairs changed 17
# iter: 1 i:344, pairs changed 17
# iter: 1 i:345, pairs changed 17
# iter: 1 i:350, pairs changed 17
# iter: 1 i:351, pairs changed 17
# iter: 1 i:354, pairs changed 17
# iter: 1 i:355, pairs changed 17
# iter: 1 i:357, pairs changed 17
# iter: 1 i:358, pairs changed 17
# iter: 1 i:359, pairs changed 17
# iter: 1 i:363, pairs changed 17
# iter: 1 i:368, pairs changed 17
# iter: 1 i:370, pairs changed 17
# iter: 1 i:372, pairs changed 17
# iter: 1 i:374, pairs changed 17
# iter: 1 i:379, pairs changed 17
# iter: 1 i:382, pairs changed 17
# iter: 1 i:388, pairs changed 17
# iter: 1 i:393, pairs changed 17
# iter: 1 i:394, pairs changed 17
# iter: 1 i:398, pairs changed 17
# iter: 1 i:399, pairs changed 17
# iter: 1 i:406, pairs changed 17
# iter: 1 i:412, pairs changed 17
# iter: 1 i:416, pairs changed 17
# iter: 1 i:427, pairs changed 17
# iter: 1 i:428, pairs changed 17
# iter: 1 i:429, pairs changed 17
# iter: 1 i:435, pairs changed 17
# iter: 1 i:444, pairs changed 17
# iter: 1 i:450, pairs changed 17
# iter: 1 i:454, pairs changed 17
# iter: 1 i:455, pairs changed 17
# iter: 1 i:458, pairs changed 17
# iter: 1 i:459, pairs changed 17
# iter: 1 i:462, pairs changed 17
# iter: 1 i:464, pairs changed 17
# iter: 1 i:478, pairs changed 17
# iter: 1 i:500, pairs changed 17
# iter: 1 i:503, pairs changed 17
# iter: 1 i:507, pairs changed 17
# iter: 1 i:518, pairs changed 17
# iter: 1 i:519, pairs changed 17
# iter: 1 i:526, pairs changed 17
# iter: 1 i:533, pairs changed 17
# iter: 1 i:545, pairs changed 17
# iter: 1 i:556, pairs changed 17
# iter: 1 i:560, pairs changed 17
# iter: 1 i:566, pairs changed 17
# iter: 1 i:572, pairs changed 17
# iter: 1 i:573, pairs changed 17
# iter: 1 i:577, pairs changed 17
# iter: 1 i:593, pairs changed 17
# iter: 1 i:600, pairs changed 17
# iter: 1 i:603, pairs changed 17
# iter: 1 i:618, pairs changed 17
# iter: 1 i:634, pairs changed 17
# iter: 1 i:638, pairs changed 17
# iter: 1 i:639, pairs changed 17
# iter: 1 i:641, pairs changed 17
# iter: 1 i:650, pairs changed 17
# iter: 1 i:656, pairs changed 17
# iter: 1 i:661, pairs changed 17
# iter: 1 i:664, pairs changed 17
# iter: 1 i:669, pairs changed 17
# iter: 1 i:671, pairs changed 17
# iter: 1 i:678, pairs changed 17
# iter: 1 i:688, pairs changed 17
# iter: 1 i:689, pairs changed 17
# iter: 1 i:691, pairs changed 17
# iter: 1 i:694, pairs changed 17
# iter: 1 i:702, pairs changed 17
# iter: 1 i:706, pairs changed 17
# iter: 1 i:708, pairs changed 17
# iter: 1 i:709, pairs changed 17
# iter: 1 i:710, pairs changed 17
# iter: 1 i:720, pairs changed 17
# iter: 1 i:728, pairs changed 17
# iter: 1 i:733, pairs changed 17
# iter: 1 i:738, pairs changed 17
# iter: 1 i:743, pairs changed 17
# iter: 1 i:744, pairs changed 17
# iter: 1 i:745, pairs changed 17
# iter: 1 i:746, pairs changed 17
# iter: 1 i:754, pairs changed 17
# iter: 1 i:780, pairs changed 17
# iter: 1 i:781, pairs changed 17
# iter: 1 i:787, pairs changed 17
# iter: 1 i:791, pairs changed 17
# iter: 1 i:806, pairs changed 17
# iter: 1 i:810, pairs changed 17
# iter: 1 i:818, pairs changed 17
# iter: 1 i:821, pairs changed 17
# iter: 1 i:822, pairs changed 17
# iter: 1 i:824, pairs changed 17
# iter: 1 i:825, pairs changed 17
# iter: 1 i:838, pairs changed 17
# iter: 1 i:849, pairs changed 17
# iter: 1 i:852, pairs changed 17
# iter: 1 i:859, pairs changed 17
# iter: 1 i:860, pairs changed 17
# iter: 1 i:862, pairs changed 17
# iter: 1 i:864, pairs changed 17
# iter: 1 i:869, pairs changed 17
# iter: 1 i:870, pairs changed 17
# iter: 1 i:876, pairs changed 17
# iter: 1 i:884, pairs changed 17
# iter: 1 i:892, pairs changed 17
# iter: 1 i:900, pairs changed 17
# iter: 1 i:905, pairs changed 17
# iter: 1 i:915, pairs changed 17
# iter: 1 i:918, pairs changed 17
# iter: 1 i:920, pairs changed 17
# iter: 1 i:922, pairs changed 17
# iter: 1 i:927, pairs changed 17
# iter: 1 i:932, pairs changed 17
# iter: 1 i:936, pairs changed 17
# iter: 1 i:945, pairs changed 17
# iter: 1 i:948, pairs changed 17
# iter: 1 i:949, pairs changed 17
# iter: 1 i:959, pairs changed 17
# iter: 1 i:963, pairs changed 17
# iter: 1 i:968, pairs changed 17
# iter: 1 i:974, pairs changed 17
# iter: 1 i:978, pairs changed 17
# iter: 1 i:980, pairs changed 17
# iter:1:100
# iter: 2 i:1, pairs changed 0
# iter: 2 i:2, pairs changed 0
# iter: 2 i:3, pairs changed 0
# iter: 2 i:4, pairs changed 0
# iter: 2 i:5, pairs changed 0
# iter: 2 i:6, pairs changed 0
# iter: 2 i:7, pairs changed 0
# iter: 2 i:8, pairs changed 0
# iter: 2 i:9, pairs changed 0
# iter: 2 i:10, pairs changed 0
# iter: 2 i:11, pairs changed 0
# iter: 2 i:12, pairs changed 0
# iter: 2 i:13, pairs changed 0
# iter: 2 i:14, pairs changed 0
# iter: 2 i:15, pairs changed 0
# iter: 2 i:16, pairs changed 0
# iter: 2 i:17, pairs changed 0
# iter: 2 i:18, pairs changed 0
# iter: 2 i:19, pairs changed 0
# iter: 2 i:20, pairs changed 0
# iter: 2 i:21, pairs changed 0
# iter: 2 i:22, pairs changed 0
# iter: 2 i:23, pairs changed 0
# iter: 2 i:24, pairs changed 0
# iter: 2 i:26, pairs changed 0
# iter: 2 i:28, pairs changed 0
# iter: 2 i:29, pairs changed 0
# iter: 2 i:30, pairs changed 0
# iter: 2 i:31, pairs changed 0
# iter: 2 i:32, pairs changed 0
# iter: 2 i:33, pairs changed 0
# iter: 2 i:34, pairs changed 0
# iter: 2 i:35, pairs changed 0
# iter: 2 i:36, pairs changed 0
# iter: 2 i:37, pairs changed 0
# iter: 2 i:38, pairs changed 0
# iter: 2 i:40, pairs changed 0
# iter: 2 i:41, pairs changed 0
# iter: 2 i:42, pairs changed 0
# iter: 2 i:43, pairs changed 0
# iter: 2 i:44, pairs changed 0
# iter: 2 i:45, pairs changed 0
# iter: 2 i:46, pairs changed 0
# iter: 2 i:51, pairs changed 0
# iter: 2 i:53, pairs changed 0
# iter: 2 i:54, pairs changed 0
# iter: 2 i:55, pairs changed 0
# iter: 2 i:56, pairs changed 0
# iter: 2 i:57, pairs changed 0
# iter: 2 i:58, pairs changed 0
# iter: 2 i:61, pairs changed 0
# iter: 2 i:63, pairs changed 0
# iter: 2 i:67, pairs changed 0
# iter: 2 i:68, pairs changed 0
# iter: 2 i:70, pairs changed 0
# iter: 2 i:72, pairs changed 0
# iter: 2 i:75, pairs changed 0
# iter: 2 i:78, pairs changed 0
# iter: 2 i:81, pairs changed 0
# iter: 2 i:95, pairs changed 0
# iter: 2 i:97, pairs changed 0
# iter: 2 i:99, pairs changed 0
# iter: 2 i:102, pairs changed 0
# iter: 2 i:104, pairs changed 0
# iter: 2 i:112, pairs changed 0
# iter: 2 i:113, pairs changed 0
# iter: 2 i:114, pairs changed 0
# iter: 2 i:119, pairs changed 0
# iter: 2 i:122, pairs changed 0
# iter: 2 i:128, pairs changed 0
# iter: 2 i:133, pairs changed 0
# iter: 2 i:134, pairs changed 0
# iter: 2 i:137, pairs changed 0
# iter: 2 i:142, pairs changed 0
# iter: 2 i:143, pairs changed 0
# iter: 2 i:147, pairs changed 0
# iter: 2 i:153, pairs changed 0
# iter: 2 i:160, pairs changed 0
# iter: 2 i:162, pairs changed 0
# iter: 2 i:163, pairs changed 0
# iter: 2 i:166, pairs changed 0
# iter: 2 i:168, pairs changed 0
# iter: 2 i:170, pairs changed 0
# iter: 2 i:174, pairs changed 0
# iter: 2 i:176, pairs changed 0
# iter: 2 i:177, pairs changed 0
# iter: 2 i:180, pairs changed 0
# iter: 2 i:183, pairs changed 0
# iter: 2 i:184, pairs changed 0
# iter: 2 i:192, pairs changed 0
# iter: 2 i:197, pairs changed 0
# iter: 2 i:200, pairs changed 0
# iter: 2 i:204, pairs changed 0
# iter: 2 i:208, pairs changed 0
# iter: 2 i:209, pairs changed 0
# iter: 2 i:211, pairs changed 0
# iter: 2 i:212, pairs changed 0
# iter: 2 i:226, pairs changed 0
# iter: 2 i:227, pairs changed 0
# iter: 2 i:229, pairs changed 0
# iter: 2 i:231, pairs changed 0
# iter: 2 i:240, pairs changed 0
# iter: 2 i:247, pairs changed 0
# iter: 2 i:248, pairs changed 0
# iter: 2 i:249, pairs changed 0
# iter: 2 i:251, pairs changed 0
# iter: 2 i:252, pairs changed 0
# iter: 2 i:264, pairs changed 0
# iter: 2 i:267, pairs changed 0
# iter: 2 i:276, pairs changed 0
# iter: 2 i:283, pairs changed 0
# iter: 2 i:285, pairs changed 0
# iter: 2 i:286, pairs changed 0
# iter: 2 i:292, pairs changed 0
# iter: 2 i:293, pairs changed 0
# iter: 2 i:296, pairs changed 0
# iter: 2 i:303, pairs changed 0
# iter: 2 i:310, pairs changed 0
# iter: 2 i:313, pairs changed 0
# iter: 2 i:315, pairs changed 0
# iter: 2 i:326, pairs changed 0
# iter: 2 i:343, pairs changed 0
# iter: 2 i:344, pairs changed 0
# iter: 2 i:345, pairs changed 0
# iter: 2 i:350, pairs changed 0
# iter: 2 i:351, pairs changed 0
# iter: 2 i:354, pairs changed 0
# iter: 2 i:355, pairs changed 0
# iter: 2 i:357, pairs changed 0
# iter: 2 i:358, pairs changed 0
# iter: 2 i:359, pairs changed 0
# iter: 2 i:363, pairs changed 0
# iter: 2 i:368, pairs changed 0
# iter: 2 i:370, pairs changed 0
# iter: 2 i:372, pairs changed 0
# iter: 2 i:374, pairs changed 0
# iter: 2 i:379, pairs changed 0
# iter: 2 i:382, pairs changed 0
# iter: 2 i:388, pairs changed 0
# iter: 2 i:393, pairs changed 0
# iter: 2 i:394, pairs changed 0
# iter: 2 i:398, pairs changed 0
# iter: 2 i:399, pairs changed 0
# iter: 2 i:406, pairs changed 0
# iter: 2 i:412, pairs changed 0
# iter: 2 i:416, pairs changed 0
# iter: 2 i:427, pairs changed 0
# iter: 2 i:428, pairs changed 0
# iter: 2 i:429, pairs changed 0
# iter: 2 i:435, pairs changed 0
# iter: 2 i:444, pairs changed 0
# iter: 2 i:450, pairs changed 0
# iter: 2 i:454, pairs changed 0
# iter: 2 i:455, pairs changed 0
# iter: 2 i:458, pairs changed 0
# iter: 2 i:459, pairs changed 0
# iter: 2 i:462, pairs changed 0
# iter: 2 i:464, pairs changed 0
# iter: 2 i:478, pairs changed 0
# iter: 2 i:500, pairs changed 0
# iter: 2 i:503, pairs changed 0
# iter: 2 i:507, pairs changed 0
# iter: 2 i:518, pairs changed 0
# iter: 2 i:519, pairs changed 0
# iter: 2 i:526, pairs changed 0
# iter: 2 i:533, pairs changed 0
# iter: 2 i:545, pairs changed 0
# iter: 2 i:556, pairs changed 0
# iter: 2 i:560, pairs changed 0
# iter: 2 i:566, pairs changed 0
# iter: 2 i:572, pairs changed 0
# iter: 2 i:573, pairs changed 0
# iter: 2 i:577, pairs changed 0
# iter: 2 i:593, pairs changed 0
# iter: 2 i:600, pairs changed 0
# iter: 2 i:603, pairs changed 0
# iter: 2 i:618, pairs changed 0
# iter: 2 i:634, pairs changed 0
# iter: 2 i:638, pairs changed 0
# iter: 2 i:639, pairs changed 0
# iter: 2 i:641, pairs changed 0
# iter: 2 i:650, pairs changed 0
# iter: 2 i:656, pairs changed 0
# iter: 2 i:661, pairs changed 0
# iter: 2 i:664, pairs changed 0
# iter: 2 i:669, pairs changed 0
# iter: 2 i:671, pairs changed 0
# iter: 2 i:678, pairs changed 0
# iter: 2 i:688, pairs changed 0
# iter: 2 i:689, pairs changed 0
# iter: 2 i:691, pairs changed 0
# iter: 2 i:694, pairs changed 0
# iter: 2 i:702, pairs changed 0
# iter: 2 i:706, pairs changed 0
# iter: 2 i:708, pairs changed 0
# iter: 2 i:709, pairs changed 0
# iter: 2 i:710, pairs changed 0
# iter: 2 i:720, pairs changed 0
# iter: 2 i:728, pairs changed 0
# iter: 2 i:733, pairs changed 0
# iter: 2 i:738, pairs changed 0
# iter: 2 i:743, pairs changed 0
# iter: 2 i:744, pairs changed 0
# iter: 2 i:745, pairs changed 0
# iter: 2 i:746, pairs changed 0
# iter: 2 i:754, pairs changed 0
# iter: 2 i:780, pairs changed 0
# iter: 2 i:781, pairs changed 0
# iter: 2 i:787, pairs changed 0
# iter: 2 i:791, pairs changed 0
# iter: 2 i:806, pairs changed 0
# iter: 2 i:810, pairs changed 0
# iter: 2 i:818, pairs changed 0
# iter: 2 i:821, pairs changed 0
# iter: 2 i:822, pairs changed 0
# iter: 2 i:824, pairs changed 0
# iter: 2 i:825, pairs changed 0
# iter: 2 i:838, pairs changed 0
# iter: 2 i:849, pairs changed 0
# iter: 2 i:852, pairs changed 0
# iter: 2 i:859, pairs changed 0
# iter: 2 i:860, pairs changed 0
# iter: 2 i:862, pairs changed 0
# iter: 2 i:864, pairs changed 0
# iter: 2 i:869, pairs changed 0
# iter: 2 i:870, pairs changed 0
# iter: 2 i:876, pairs changed 0
# iter: 2 i:884, pairs changed 0
# iter: 2 i:892, pairs changed 0
# iter: 2 i:900, pairs changed 0
# iter: 2 i:905, pairs changed 0
# iter: 2 i:915, pairs changed 0
# iter: 2 i:918, pairs changed 0
# iter: 2 i:920, pairs changed 0
# iter: 2 i:922, pairs changed 0
# iter: 2 i:927, pairs changed 0
# iter: 2 i:932, pairs changed 0
# iter: 2 i:936, pairs changed 0
# iter: 2 i:945, pairs changed 0
# iter: 2 i:948, pairs changed 0
# iter: 2 i:949, pairs changed 0
# iter: 2 i:959, pairs changed 0
# iter: 2 i:963, pairs changed 0
# iter: 2 i:968, pairs changed 0
# iter: 2 i:974, pairs changed 0
# iter: 2 i:978, pairs changed 0
# iter: 2 i:980, pairs changed 0
# start to test
# test:0:100
# test:1:100
# test:2:100
# test:3:100
# test:4:100
# test:5:100
# test:6:100
# test:7:100
# test:8:100
# test:9:100
# test:10:100
# test:11:100
# test:12:100
# test:13:100
# test:14:100
# test:15:100
# test:16:100
# test:17:100
# test:18:100
# test:19:100
# test:20:100
# test:21:100
# test:22:100
# test:23:100
# test:24:100
# test:25:100
# test:26:100
# test:27:100
# test:28:100
# test:29:100
# test:30:100
# test:31:100
# test:32:100
# test:33:100
# test:34:100
# test:35:100
# test:36:100
# test:37:100
# test:38:100
# test:39:100
# test:40:100
# test:41:100
# test:42:100
# test:43:100
# test:44:100
# test:45:100
# test:46:100
# test:47:100
# test:48:100
# test:49:100
# test:50:100
# test:51:100
# test:52:100
# test:53:100
# test:54:100
# test:55:100
# test:56:100
# test:57:100
# test:58:100
# test:59:100
# test:60:100
# test:61:100
# test:62:100
# test:63:100
# test:64:100
# test:65:100
# test:66:100
# test:67:100
# test:68:100
# test:69:100
# test:70:100
# test:71:100
# test:72:100
# test:73:100
# test:74:100
# test:75:100
# test:76:100
# test:77:100
# test:78:100
# test:79:100
# test:80:100
# test:81:100
# test:82:100
# test:83:100
# test:84:100
# test:85:100
# test:86:100
# test:87:100
# test:88:100
# test:89:100
# test:90:100
# test:91:100
# test:92:100
# test:93:100
# test:94:100
# test:95:100
# test:96:100
# test:97:100
# test:98:100
# test:99:100
# the accuracy is: 0.97
